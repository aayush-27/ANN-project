# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 0.0001
counts = Counter(int_words)
total = len(int_words)
prob = {i : np.sqrt(threshold*total/counts[i]) for i in set(int_words)}
train_words = [x for x in int_words if random.random() < prob[x]]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R=np.random.randint(1,window_size+1)
    end = len(words)
    if idx-R>=0 and idx+R<end:
      return words[idx-R:idx]+words[idx+1:idx+R]
    elif idx-R>=0 and idx+R>=end :
      return words[idx-R:idx]+words[idx+1:end]
    elif idx-R<=0 and idx+R<end :
      return words[0:idx]+words[idx+1:idx+R]
    else :
      return words[0:idx]+words[idx+1:end]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None,1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding))) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding),stddev=1.0 / np.sqrt(n_embedding))) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-18-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.0736 0.0477 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 4.9471 0.0294 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1713 0.0295 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7510 0.0296 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.0271 0.0297 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 6.2037 0.0298 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 6.4900 0.0296 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 6.4572 0.0296 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 6.5710 0.0295 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 6.6681 0.0292 sec/batch
# Nearest to two: myocardial, dancesport, nisj, nic, mwh, eprom, funky, tann,
# Nearest to after: bottomed, potions, pharisee, exhorted, gomera, conditioners, vostok, standup,
# Nearest to who: kirghiz, shoeing, elegiac, reid, persecuting, surnamed, unknown, postmillennial,
# Nearest to and: kabaddi, rerio, unbundling, anarchy, obstacle, anglicans, proctor, trills,
# Nearest to up: moriarty, vian, cahiers, sqq, xxxg, keyboardist, indexed, muentzer,
# Nearest to this: watertight, proliferate, chola, kao, bitmaps, immanent, infinitesimals, bananas,
# Nearest to can: chalmers, clarion, autocracy, troposphere, pagoda, autumnal, heroines, anaesthesia,
# Nearest to that: woodside, kang, kor, sorrowful, kedah, kew, diseased, cession,
# Nearest to accepted: maguey, kitsch, angled, lightsabers, notch, butane, brasenose, reimplemented,
# Nearest to channel: alfaro, shintoism, saltpeter, theodicy, minarchists, mississippi, neogene, pleasantville,
# Nearest to magazine: physicalism, doak, quran, thulsa, bronislaw, defying, armin, cheech,
# Nearest to mean: trypomastigotes, ushering, haihowak, feldman, travertine, rockne, amyotrophic, harking,
# Nearest to versions: hernando, abjuration, gladly, misty, cappadocia, tezuka, zalta, scriptorium,
# Nearest to something: taupin, panarion, himalia, benhavn, campeador, ilha, hadadezer, streisand,
# Nearest to construction: toonopedia, kwajalein, ahijah, technische, acth, condensate, overload, sorensen,
# Nearest to report: karbala, viaje, naturalisation, defuse, eigenvector, allosteric, kilby, swordsmiths,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 6.6174 0.0307 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 6.7138 0.0294 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 6.6374 0.0294 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 6.6463 0.0293 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 6.6222 0.0296 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 6.4889 0.0294 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 6.5588 0.0297 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 6.5530 0.0294 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 6.4473 0.0295 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 6.4049 0.0293 sec/batch
# Nearest to two: myocardial, nisj, eprom, dancesport, sweeteners, tann, mecklenburg, barclay,
# Nearest to after: bottomed, pharisee, potions, exhorted, standup, gomera, vostok, wool,
# Nearest to who: kirghiz, unknown, reid, shoeing, elegiac, surnamed, postmillennial, glider,
# Nearest to and: kabaddi, rerio, unbundling, anarchy, anglicans, swell, trills, proctor,
# Nearest to up: moriarty, vian, sqq, cahiers, indexed, keyboardist, xxxg, muentzer,
# Nearest to this: watertight, proliferate, kao, chola, bitmaps, immanent, genomics, bananas,
# Nearest to can: troposphere, chalmers, autocracy, clarion, reads, pagoda, vortices, cowards,
# Nearest to that: woodside, kang, diseased, sorrowful, kor, kedah, cession, gripped,
# Nearest to accepted: brasenose, butane, lightsabers, maguey, kitsch, schleswig, builds, notch,
# Nearest to channel: alfaro, shintoism, theodicy, saltpeter, pleasantville, klerk, taxonomically, minarchists,
# Nearest to magazine: physicalism, nasa, expellees, delaney, cicely, quran, galvanic, pieds,
# Nearest to mean: feldman, trypomastigotes, travertine, urpmi, ushering, pavlovich, repudiating, virologist,
# Nearest to versions: gladly, tuareg, cappadocia, degeneration, bessemer, shipyards, pf, naruto,
# Nearest to something: taupin, panarion, hadadezer, ilha, streisand, campeador, affaires, auchinleck,
# Nearest to construction: ahijah, forbid, technische, toonopedia, kwajalein, michaux, condensate, sequencer,
# Nearest to report: eigenvector, naturalisation, pseudomonas, yuko, kilby, defuse, viaje, corum,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 6.3061 0.0303 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 6.1698 0.0297 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 6.2874 0.0295 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 6.0543 0.0294 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 6.2389 0.0294 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 6.1463 0.0294 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 5.9936 0.0293 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 6.2124 0.0295 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 6.0100 0.0295 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 6.0832 0.0294 sec/batch
# Nearest to two: zero, nisj, eprom, tann, myocardial, mecklenburg, barclay, sweeteners,
# Nearest to after: bottomed, pharisee, potions, standup, exhorted, gomera, mellows, vostok,
# Nearest to who: kirghiz, shoeing, reid, elegiac, persecuting, glider, postmillennial, gilroy,
# Nearest to and: kabaddi, rerio, anglicans, unbundling, anarchy, proctor, trills, swell,
# Nearest to up: vian, moriarty, cahiers, sqq, indexed, keyboardist, xxxg, euros,
# Nearest to this: watertight, kao, genomics, chola, bananas, proliferate, athos, shines,
# Nearest to can: troposphere, autocracy, chalmers, clarion, pagoda, vortices, cowards, autumnal,
# Nearest to that: kang, kor, diseased, kedah, woodside, cession, sorrowful, jenner,
# Nearest to accepted: builds, butane, schleswig, athelstan, kitsch, brasenose, notch, lightsabers,
# Nearest to channel: alfaro, mississippi, shintoism, theodicy, taxonomically, pleasantville, saltpeter, paigc,
# Nearest to magazine: nasa, physicalism, expellees, delaney, osgood, galvanic, cicely, pieds,
# Nearest to mean: feldman, trypomastigotes, pavlovich, repudiating, travertine, impediments, urpmi, ushering,
# Nearest to versions: gladly, degeneration, cappadocia, shipyards, tuareg, naruto, bessemer, pf,
# Nearest to something: taupin, panarion, hadadezer, streisand, ilha, campeador, benhavn, affaires,
# Nearest to construction: ahijah, toonopedia, forbid, technische, michaux, sorensen, kwajalein, acth,
# Nearest to report: defuse, thunderstorm, pseudomonas, naturalisation, eigenvector, corum, kilby, yuko,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 6.0422 0.0302 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 6.0662 0.0293 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 5.7592 0.0298 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 5.8554 0.0295 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 5.9537 0.0293 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 5.9619 0.0296 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 5.8835 0.0295 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 5.9359 0.0294 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 5.7104 0.0293 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 5.8125 0.0294 sec/batch
# Nearest to two: zero, three, one, nisj, eprom, mujahedin, tann, textes,
# Nearest to after: potions, bottomed, pharisee, exhorted, gomera, mellows, standup, glorification,
# Nearest to who: reid, persecuting, shoeing, kirghiz, elegiac, unknown, glider, gilroy,
# Nearest to and: kabaddi, trills, noob, unbundling, rerio, duvalier, anglicans, retard,
# Nearest to up: moriarty, vian, cahiers, sqq, keyboardist, xxxg, volkssturm, freenet,
# Nearest to this: watertight, kao, chola, shines, bananas, calories, inlay, uncaring,
# Nearest to can: troposphere, autocracy, chalmers, cowards, autumnal, clarion, freyr, wallingford,
# Nearest to that: kedah, kor, kang, diseased, cession, myocardium, dartmouth, sealy,
# Nearest to accepted: butane, brasenose, kitsch, lightsabers, athelstan, hamilcar, maguey, angled,
# Nearest to channel: alfaro, shintoism, theodicy, taxonomically, mississippi, pleasantville, sightings, paigc,
# Nearest to magazine: nasa, physicalism, expellees, laureates, delaney, pieds, quran, randall,
# Nearest to mean: impediments, pavlovich, repudiating, feldman, trypomastigotes, travertine, comedienne, newsletters,
# Nearest to versions: gladly, degeneration, shipyards, cappadocia, bessemer, hernando, tuareg, naruto,
# Nearest to something: taupin, panarion, hadadezer, streisand, ilha, catalonia, standings, benhavn,
# Nearest to construction: ahijah, forbid, toonopedia, michaux, technische, sorensen, bryce, congolese,
# Nearest to report: pseudomonas, corum, thunderstorm, eigenvector, defuse, kilby, naturalisation, ramen,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 5.8444 0.0302 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 5.7430 0.0292 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 5.7420 0.0294 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 5.5517 0.0294 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 5.5942 0.0295 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 5.5732 0.0293 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 5.7064 0.0225 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 5.6897 0.0294 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 5.7390 0.0293 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 5.6908 0.0294 sec/batch
# Nearest to two: zero, three, one, five, eight, four, nine, seven,
# Nearest to after: potions, bottomed, contrary, exhorted, gomera, reconstructing, glorification, mellows,
# Nearest to who: persecuting, elegiac, shoeing, kirghiz, years, validation, grinch, thesaurus,
# Nearest to and: in, by, of, this, at, kabaddi, retard, noob,
# Nearest to up: moriarty, vian, cahiers, xxxg, sqq, keyboardist, volkssturm, morphism,
# Nearest to this: of, the, shines, calories, watertight, chola, bananas, uncaring,
# Nearest to can: troposphere, autocracy, autumnal, potsdam, cowards, freyr, wallingford, chalmers,
# Nearest to that: kedah, indomitable, kor, ruck, dartmouth, cession, stream, stakeholder,
# Nearest to accepted: brasenose, butane, broomstick, athelstan, angled, extrapolating, femmes, cracow,
# Nearest to channel: alfaro, shintoism, mississippi, theodicy, taxonomically, style, sightings, pleasantville,
# Nearest to magazine: laureates, expellees, physicalism, cicely, pieds, quran, bronislaw, delaney,
# Nearest to mean: pavlovich, trypomastigotes, impediments, comedienne, repudiating, travertine, ushering, ethelred,
# Nearest to versions: gladly, bessemer, degeneration, hernando, kraus, cappadocia, pf, naruto,
# Nearest to something: taupin, panarion, ilha, hadadezer, bellerophon, wolfhounds, mindaugas, standings,
# Nearest to construction: ahijah, technische, toonopedia, sorensen, forbid, michaux, bryce, autocannon,
# Nearest to report: pseudomonas, corum, kilby, eigenvector, defuse, naturalisation, thunderstorm, octopuses,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 5.6464 0.0306 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 5.6016 0.0294 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 5.4069 0.0293 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 5.5249 0.0292 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 5.4594 0.0293 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 5.5116 0.0292 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 5.4299 0.0293 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 5.4225 0.0297 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 5.3959 0.0294 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 5.5257 0.0292 sec/batch
# Nearest to two: zero, three, one, five, four, nine, eight, seven,
# Nearest to after: in, contrary, the, six, published, potions, this, bottomed,
# Nearest to who: years, unknown, numbers, persecuting, to, personal, the, elegiac,
# Nearest to and: by, in, this, for, of, at, during, as,
# Nearest to up: xxxg, volkssturm, vian, moriarty, bentine, morphism, esdi, cahiers,
# Nearest to this: of, the, and, it, for, shines, second, they,
# Nearest to can: troposphere, wallingford, potsdam, cowards, freyr, autumnal, autocracy, luiz,
# Nearest to that: the, by, as, stream, government, for, indomitable, same,
# Nearest to accepted: brasenose, extrapolating, angled, broomstick, femmes, cracow, reimplemented, butane,
# Nearest to channel: style, mississippi, shintoism, sightings, alfaro, theodicy, pleasantville, taxonomically,
# Nearest to magazine: physicalism, cicely, expellees, bronislaw, laureates, pieds, armin, jahannam,
# Nearest to mean: repudiating, comedienne, pavlovich, impediments, trypomastigotes, ushering, travertine, capcom,
# Nearest to versions: gladly, naruto, kraus, hernando, bessemer, paget, scriptorium, cappadocia,
# Nearest to something: taupin, ilha, hadadezer, wolfhounds, bellerophon, panarion, mindaugas, mcmillan,
# Nearest to construction: technische, toonopedia, ahijah, forbid, raphaelite, autocannon, bryce, sorensen,
# Nearest to report: pseudomonas, corum, kilby, himself, thunderstorm, eigenvector, defuse, octopuses,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 5.3662 0.0304 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 5.4025 0.0295 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 5.3627 0.0294 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 5.2368 0.0294 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 5.3402 0.0293 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 5.2697 0.0293 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 5.2663 0.0294 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 5.2250 0.0295 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 5.2812 0.0294 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 5.1498 0.0293 sec/batch
# Nearest to two: zero, three, one, five, four, seven, nine, eight,
# Nearest to after: contrary, second, published, in, went, bottomed, potions, history,
# Nearest to who: years, numbers, unknown, personal, to, the, surprising, persecuting,
# Nearest to and: by, in, during, this, for, their, has, however,
# Nearest to up: a, system, passage, grouped, volkssturm, covered, xxxg, morphism,
# Nearest to this: of, the, and, for, it, second, that, those,
# Nearest to can: not, be, that, troposphere, is, the, also, region,
# Nearest to that: as, the, by, same, be, there, than, for,
# Nearest to accepted: extrapolating, cracow, estimated, mathematics, original, builds, brasenose, dostum,
# Nearest to channel: alfaro, shintoism, theodicy, style, sightings, mississippi, pleasantville, neogene,
# Nearest to magazine: cicely, physicalism, expellees, laureates, pieds, bronislaw, nasa, jahannam,
# Nearest to mean: pavlovich, repudiating, comedienne, trypomastigotes, impediments, capcom, former, ushering,
# Nearest to versions: gladly, hernando, kraus, naruto, paget, bessemer, samarkand, capricious,
# Nearest to something: we, emotional, wolfhounds, taupin, ilha, bellerophon, whitworth, hadadezer,
# Nearest to construction: forbid, technische, toonopedia, autocannon, sorensen, ahijah, raphaelite, bryce,
# Nearest to report: himself, pseudomonas, kilby, corum, octopuses, thunderstorm, naturalisation, stares,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 5.2630 0.0302 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 5.1639 0.0292 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 5.1124 0.0295 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 5.1803 0.0293 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 5.1608 0.0292 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 5.1134 0.0292 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 5.1716 0.0294 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 5.1499 0.0295 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 5.0598 0.0296 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 5.1587 0.0294 sec/batch
# Nearest to two: zero, three, one, five, seven, four, eight, nine,
# Nearest to after: second, went, published, contrary, member, week, continued, in,
# Nearest to who: unknown, personal, better, numbers, years, surprising, maintain, procedure,
# Nearest to and: by, this, during, particularly, in, continued, policy, main,
# Nearest to up: grouped, passage, a, system, around, volkssturm, covered, consequently,
# Nearest to this: of, the, that, and, those, for, it, grouped,
# Nearest to can: be, not, that, is, are, than, seen, ways,
# Nearest to that: be, as, possible, can, same, than, the, there,
# Nearest to accepted: themselves, mathematics, estimated, original, extrapolating, description, stemming, heard,
# Nearest to channel: style, mississippi, sightings, theodicy, shintoism, alfaro, pleasantville, neogene,
# Nearest to magazine: nasa, cicely, conversation, physicalism, pagan, expellees, noted, hypnotist,
# Nearest to mean: we, or, examples, virtually, decide, informal, us, innovation,
# Nearest to versions: gladly, kenneth, samarkand, kraus, capricious, paget, suspended, slapped,
# Nearest to something: we, applying, emotional, if, example, modern, constructions, regulation,
# Nearest to construction: toonopedia, forbid, autocannon, sorensen, technische, written, tetrahedra, raphaelite,
# Nearest to report: himself, professions, however, realized, pseudomonas, kilby, octopuses, corum,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 5.0227 0.0303 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 5.0718 0.0296 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.9708 0.0294 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 5.1246 0.0292 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 5.2119 0.0292 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 5.0900 0.0296 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 5.1004 0.0291 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 5.0764 0.0293 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 5.0185 0.0295 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.9035 0.0295 sec/batch
# Nearest to two: zero, three, one, five, four, nine, eight, seven,
# Nearest to after: went, second, officially, member, chancellor, in, continued, fought,
# Nearest to who: personal, unknown, better, reid, years, christian, maintain, surprising,
# Nearest to and: by, support, economy, main, during, policy, countries, in,
# Nearest to up: grouped, passage, a, consequently, covered, arrangement, system, morphism,
# Nearest to this: of, that, it, systems, connection, the, for, grouped,
# Nearest to can: be, that, not, are, is, example, we, suppose,
# Nearest to that: be, can, as, possible, therefore, laws, example, not,
# Nearest to accepted: mathematics, limiting, stemming, themselves, original, description, heard, builds,
# Nearest to channel: shintoism, theodicy, mississippi, style, alfaro, pleasantville, neogene, taxonomically,
# Nearest to magazine: cicely, nasa, physicalism, conversation, pieds, expellees, markets, scores,
# Nearest to mean: or, we, examples, informal, decide, difference, inevitably, calculated,
# Nearest to versions: gladly, kenneth, compiled, thought, suspended, samarkand, counterpart, countless,
# Nearest to something: we, emotional, applying, if, going, example, must, christians,
# Nearest to construction: forbid, written, toonopedia, sorensen, technische, at, national, autocannon,
# Nearest to report: himself, professions, however, realized, proponents, conservative, approved, generations,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.9405 0.0302 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.9507 0.0293 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 5.0457 0.0155 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 5.0040 0.0300 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 5.0469 0.0300 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.9823 0.0299 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.9091 0.0292 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.9340 0.0295 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.9855 0.0294 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.8409 0.0294 sec/batch
# Nearest to two: zero, three, five, one, four, seven, nine, eight,
# Nearest to after: fought, went, officially, continued, member, chancellor, second, in,
# Nearest to who: personal, christian, years, reid, unknown, conflict, maintain, usenet,
# Nearest to and: by, economy, in, continued, main, countries, noob, originally,
# Nearest to up: arrangement, grouped, passage, a, xxxg, morphism, rhyme, equipped,
# Nearest to this: of, systems, shines, that, computers, connection, grouped, it,
# Nearest to can: be, that, not, example, are, is, integer, suppose,
# Nearest to that: be, can, possible, laws, as, therefore, example, do,
# Nearest to accepted: themselves, mathematics, description, limiting, stemming, hierarchy, heard, extrapolating,
# Nearest to channel: mississippi, style, theodicy, shintoism, sightings, consumer, fm, alfaro,
# Nearest to magazine: cicely, conversation, nasa, physicalism, markets, fare, laureates, business,
# Nearest to mean: or, we, difference, argument, examples, functions, calculated, numerical,
# Nearest to versions: compiled, more, countless, capricious, counterpart, feature, thought, gladly,
# Nearest to something: we, applying, emotional, if, must, example, tends, reason,
# Nearest to construction: forbid, sorensen, technische, raphaelite, at, dimension, tetrahedra, toonopedia,
# Nearest to report: himself, professions, invalid, proponents, however, serious, kilby, corum,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.8915 0.0303 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.8826 0.0291 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.8768 0.0292 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.7579 0.0294 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.8076 0.0293 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.8092 0.0291 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.8962 0.0292 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.7780 0.0294 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.7872 0.0301 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.7964 0.0297 sec/batch
# Nearest to two: zero, three, five, four, one, seven, six, nine,
# Nearest to after: went, fought, had, officially, continued, divisional, evacuated, during,
# Nearest to who: reid, christian, personal, years, exercising, age, prison, jew,
# Nearest to and: by, main, enhanced, this, particularly, countries, noob, economy,
# Nearest to up: arrangement, grouped, passage, a, beneficial, equipped, consequently, covered,
# Nearest to this: of, systems, processes, quantity, measurements, shines, logically, that,
# Nearest to can: be, are, example, not, simple, suppose, integer, is,
# Nearest to that: be, laws, as, can, therefore, do, valid, not,
# Nearest to accepted: themselves, hierarchy, stemming, description, mathematics, limiting, emotional, related,
# Nearest to channel: mississippi, stations, fm, sightings, style, radios, services, viceroy,
# Nearest to magazine: cicely, conversation, fare, nasa, laureates, physicalism, scores, philosopher,
# Nearest to mean: we, difference, functions, numerical, or, argument, examples, advantages,
# Nearest to versions: compiled, hardware, computers, more, feature, computer, pc, interface,
# Nearest to something: we, applying, emotional, else, if, know, must, interpreted,
# Nearest to construction: forbid, traditionally, reaches, and, manufactured, petroleum, sorensen, tourism,
# Nearest to report: professions, himself, invalid, anonymity, presiding, proponents, register, generations,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.8027 0.0302 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.7917 0.0291 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.6873 0.0293 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.6379 0.0292 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.7103 0.0291 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.7003 0.0293 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.6231 0.0291 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.6680 0.0294 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.5706 0.0293 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.6786 0.0295 sec/batch
# Nearest to two: zero, three, five, one, four, seven, six, eight,
# Nearest to after: during, went, had, evacuated, fought, officially, invaded, divisional,
# Nearest to who: personal, christian, reid, prison, punitive, jew, exercising, conflict,
# Nearest to and: by, main, in, particularly, enhanced, unbundling, countries, funchal,
# Nearest to up: arrangement, equipped, a, beneficial, pools, grouped, passage, covered,
# Nearest to this: of, that, acceleration, shines, assign, logically, connection, measurements,
# Nearest to can: be, are, ways, uniquely, formulation, not, means, computed,
# Nearest to that: be, laws, as, do, therefore, evaluate, valid, deny,
# Nearest to accepted: themselves, hierarchy, description, stemming, philosophy, merely, orthodox, strabo,
# Nearest to channel: fm, stations, mississippi, radios, radio, services, located, sightings,
# Nearest to magazine: cicely, conversation, fare, philosopher, randall, physicalism, laureates, seven,
# Nearest to mean: we, parameter, calculated, numerical, difference, argument, functions, or,
# Nearest to versions: compiled, hardware, interface, computer, computers, platforms, pc, feature,
# Nearest to something: we, emotional, applying, know, else, interpreted, if, reason,
# Nearest to construction: reaches, manufactured, fuels, petroleum, sorensen, kerguelen, autocannon, queenie,
# Nearest to report: professions, adjustment, presiding, anonymity, allegation, retaliation, analyst, proponents,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.7050 0.0303 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.5968 0.0292 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.6422 0.0292 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.6146 0.0292 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.6342 0.0292 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.6557 0.0291 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.5925 0.0292 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.5933 0.0292 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.5420 0.0291 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.6842 0.0293 sec/batch
# Nearest to two: zero, three, five, four, one, seven, eight, nine,
# Nearest to after: had, during, went, fought, evacuated, continued, victories, the,
# Nearest to who: christian, jew, personal, himself, refused, prison, fathers, he,
# Nearest to and: by, in, unbundling, during, mediterranean, cae, main, iehouah,
# Nearest to up: arrangement, pools, passage, covered, equipped, saves, around, afraid,
# Nearest to this: of, shines, connection, second, that, the, assign, chola,
# Nearest to can: uniquely, integer, be, computed, expression, suppose, solved, multiplied,
# Nearest to that: laws, deny, stated, be, as, intend, return, valid,
# Nearest to accepted: hierarchy, orthodox, catholics, themselves, stemming, excommunicated, autonomy, philosophy,
# Nearest to channel: fm, stations, radios, radio, mississippi, shortwave, broadcast, network,
# Nearest to magazine: conversation, autobiographical, released, fare, musicians, best, laureates, harry,
# Nearest to mean: numerical, parameter, calculated, we, constants, functions, theorems, difference,
# Nearest to versions: compiled, hardware, interface, computer, pc, computers, platforms, windows,
# Nearest to something: we, know, else, emotional, applying, interpreted, wrong, just,
# Nearest to construction: petroleum, metro, manufactured, reaches, tourism, slopes, fuels, deposits,
# Nearest to report: professions, adjustment, approved, retaliation, anonymity, conservative, presiding, responsibility,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.7643 0.0304 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.4678 0.0292 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.6478 0.0292 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.5427 0.0297 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.4449 0.0292 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.5357 0.0292 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.5724 0.0292 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.5618 0.0293 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.5805 0.0079 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.5700 0.0292 sec/batch
# Nearest to two: zero, three, five, four, one, seven, eight, six,
# Nearest to after: went, had, during, continued, victories, fought, managed, sent,
# Nearest to who: prison, exercising, himself, personal, jew, reid, her, age,
# Nearest to and: by, main, in, unbundling, particularly, cae, iehouah, kabaddi,
# Nearest to up: arrangement, saves, pools, compleat, once, xxxg, calcutta, volkssturm,
# Nearest to this: of, shines, the, assign, second, that, exactly, imply,
# Nearest to can: uniquely, computed, integer, converge, multiplied, suppose, be, dimensions,
# Nearest to that: intend, laws, be, as, stated, return, evaluate, perceptions,
# Nearest to accepted: hierarchy, orthodox, stemming, themselves, strabo, catholics, emotional, virtuous,
# Nearest to channel: fm, stations, radios, radio, shortwave, mississippi, broadcasting, broadcast,
# Nearest to magazine: multimedia, conversation, label, autobiographical, cartoons, pictures, released, collaborative,
# Nearest to mean: parameter, calculated, we, constants, functions, integrals, numerical, theorems,
# Nearest to versions: compiled, interface, computers, platforms, windows, hardware, pc, mac,
# Nearest to something: we, know, else, emotional, wrong, you, interpreted, doing,
# Nearest to construction: petroleum, metro, manufactured, reaches, slopes, tourism, deposits, transportation,
# Nearest to report: professions, retaliation, responsibility, conservative, iraq, approved, anonymity, adjustment,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.5278 0.0303 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.5153 0.0292 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.4859 0.0294 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.5495 0.0293 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.5610 0.0291 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.4738 0.0291 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.4982 0.0291 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.5106 0.0292 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.5322 0.0291 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.4085 0.0290 sec/batch
# Nearest to two: zero, three, five, four, one, seven, six, nine,
# Nearest to after: went, had, managed, victories, during, sent, continued, week,
# Nearest to who: prison, age, divorce, my, himself, jew, her, married,
# Nearest to and: by, main, in, unbundling, as, kabaddi, cae, particularly,
# Nearest to up: once, arrangement, league, would, unable, straight, tactic, franchise,
# Nearest to this: of, shines, second, the, measurements, assign, that, acceleration,
# Nearest to can: uniquely, computed, be, suppose, converge, circuitry, dimensions, usually,
# Nearest to that: be, valid, intend, return, possible, stated, therefore, laws,
# Nearest to accepted: hierarchy, stemming, merely, orthodox, heresy, catholics, virtuous, strabo,
# Nearest to channel: fm, stations, radios, radio, broadcasting, shortwave, broadcast, channels,
# Nearest to magazine: multimedia, conversation, autobiographical, released, label, interview, collaborative, fare,
# Nearest to mean: parameter, calculated, we, constants, numerical, theorems, geometric, functions,
# Nearest to versions: compiled, interface, platforms, pc, perl, mac, computers, pcs,
# Nearest to something: we, else, know, emotional, wrong, going, ve, doing,
# Nearest to construction: metro, manufactured, petroleum, slopes, gas, fuels, transportation, reaches,
# Nearest to report: professions, retaliation, responsibility, approved, anonymity, iraq, drug, conservative,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.3640 0.0301 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.3510 0.0288 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.4658 0.0292 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.4224 0.0291 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.3826 0.0291 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.4054 0.0292 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.4261 0.0292 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.5125 0.0291 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.3118 0.0294 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.3357 0.0292 sec/batch
# Nearest to two: zero, three, five, four, one, seven, six, nine,
# Nearest to after: went, victories, had, during, managed, evacuated, brother, continued,
# Nearest to who: my, age, reid, prison, married, personal, her, stories,
# Nearest to and: by, in, main, restricts, kabaddi, unbundling, cae, iehouah,
# Nearest to up: straight, saves, arrangement, kick, pools, drop, would, moves,
# Nearest to this: of, the, constant, shines, exactly, that, acceleration, assign,
# Nearest to can: uniquely, be, converge, expression, dimensions, suppose, computed, ways,
# Nearest to that: be, possible, as, therefore, valid, return, stated, this,
# Nearest to accepted: stemming, hierarchy, elaborated, merely, strabo, orthodox, plainly, propositions,
# Nearest to channel: fm, stations, radio, broadcasting, radios, channels, broadcast, shortwave,
# Nearest to magazine: conversation, autobiographical, cartoons, multimedia, collaborative, interview, label, villains,
# Nearest to mean: calculated, we, parameter, differentiable, categorical, integrals, is, constants,
# Nearest to versions: compiled, interface, perl, platforms, version, pc, pcs, compilers,
# Nearest to something: we, else, know, ve, think, wrong, conversation, remember,
# Nearest to construction: petroleum, metro, manufactured, slopes, fuels, transportation, deposits, textiles,
# Nearest to report: professions, anonymity, drug, adjustment, responsibility, retaliation, approved, subscribers,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.3154 0.0304 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.3955 0.0291 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.3640 0.0291 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.3471 0.0292 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.3130 0.0293 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.3062 0.0291 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.3550 0.0292 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.3028 0.0293 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.3433 0.0293 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.3430 0.0293 sec/batch
# Nearest to two: zero, three, five, four, one, seven, six, eight,
# Nearest to after: went, victories, during, had, rallied, evacuated, the, brother,
# Nearest to who: personal, prison, legitimate, friendships, jew, age, obnoxious, divorce,
# Nearest to and: in, by, main, as, unbundling, cae, iehouah, particularly,
# Nearest to up: saves, happened, league, moves, arrangement, afraid, drop, franchise,
# Nearest to this: of, second, that, the, assign, shines, exactly, and,
# Nearest to can: uniquely, be, dimensions, converge, usually, expression, lid, suppose,
# Nearest to that: possible, this, be, therefore, return, as, valid, intend,
# Nearest to accepted: stemming, autonomy, strabo, catholics, heresy, plainly, orthodox, excommunicated,
# Nearest to channel: fm, stations, broadcasting, radio, radios, broadcast, channels, television,
# Nearest to magazine: conversation, collaborative, multimedia, cartoons, interview, pictures, autobiographical, facsimile,
# Nearest to mean: parameter, we, calculated, differentiable, integrals, categorical, geometric, constants,
# Nearest to versions: compiled, perl, version, platforms, pc, windows, pcs, gui,
# Nearest to something: we, know, else, conversation, going, ve, doing, you,
# Nearest to construction: metro, petroleum, manufactured, suburbs, buses, investments, transportation, tourist,
# Nearest to report: anonymity, adjustment, drug, bureau, approved, agency, responsibility, competitiveness,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.3638 0.0303 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.2618 0.0291 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.2700 0.0290 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.3071 0.0291 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.2857 0.0293 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.3476 0.0293 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.4867 0.0291 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.2944 0.0292 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.3460 0.0292 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.3454 0.0291 sec/batch
# Nearest to two: zero, three, five, four, one, seven, six, eight,
# Nearest to after: went, managed, victories, had, rallied, during, brother, continued,
# Nearest to who: prison, friendships, personal, deuteronomy, fathers, exercising, himself, age,
# Nearest to and: main, in, by, globalization, consilience, restricts, particularly, pinafore,
# Nearest to up: saves, drop, moves, league, afraid, happened, tactic, unable,
# Nearest to this: second, of, that, multiple, constant, exactly, the, it,
# Nearest to can: uniquely, expression, suppose, be, converge, dimensions, say, assessing,
# Nearest to that: possible, this, be, return, therefore, intend, approximating, demonic,
# Nearest to accepted: stemming, heresy, strabo, plainly, judaica, martyrdom, elaborated, autonomy,
# Nearest to channel: fm, stations, broadcasting, radio, channels, radios, broadcast, shortwave,
# Nearest to magazine: collaborative, interview, conversation, autobiographical, multimedia, cartoons, magazines, newspaper,
# Nearest to mean: integrals, calculated, parameter, we, differentiable, above, is, about,
# Nearest to versions: compiled, perl, version, platforms, pc, mac, gui, compilers,
# Nearest to something: we, know, else, going, ve, conversation, isn, remember,
# Nearest to construction: metro, petroleum, suburbs, rail, transportation, investments, manufactured, slopes,
# Nearest to report: bureau, assessment, agency, retaliation, responsibility, drug, review, fbi,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.1713 0.0303 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.2854 0.0294 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.2423 0.0291 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.2344 0.0292 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.2695 0.0291 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.3103 0.0297 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.2477 0.0290 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.2838 0.0292 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.2590 0.0291 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.2596 0.0292 sec/batch
# Nearest to two: zero, three, five, four, one, seven, six, eight,
# Nearest to after: went, managed, second, half, during, had, victories, bottomed,
# Nearest to who: age, personal, friendships, servitude, legitimate, cor, prison, them,
# Nearest to and: rerio, in, main, unbundling, consilience, kabaddi, cae, gutrune,
# Nearest to up: saves, offside, tactic, happened, xxxg, winger, kick, unable,
# Nearest to this: that, of, second, the, multiple, it, exactly, just,
# Nearest to can: uniquely, qualia, usually, lid, expression, assessing, t, ways,
# Nearest to that: this, possible, be, intend, return, demonic, think, could,
# Nearest to accepted: stemming, heresy, hypotheses, plainly, elaborated, strabo, embodies, stemmed,
# Nearest to channel: fm, stations, broadcasting, radio, channels, radios, broadcast, transmitters,
# Nearest to magazine: collaborative, multimedia, peer, interview, conversation, cartoons, magazines, autobiographical,
# Nearest to mean: parameter, integrals, geometric, calculated, about, we, denotes, difference,
# Nearest to versions: compiled, version, platforms, gui, perl, pcs, hints, mac,
# Nearest to something: else, we, know, ve, conversation, going, wrong, isn,
# Nearest to construction: metro, petroleum, rail, transportation, investments, manufactured, suburbs, commuter,
# Nearest to report: assessment, review, summary, agency, bureau, anonymity, drug, analyst,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.2271 0.0301 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.1851 0.0291 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.3101 0.0291 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.2605 0.0289 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.2851 0.0293 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.2262 0.0291 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 4.1513 0.0289 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.1284 0.0291 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.1733 0.0298 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.2271 0.0299 sec/batch
# Nearest to two: zero, three, five, four, one, six, seven, eight,
# Nearest to after: went, half, second, victories, managed, during, divisional, playoff,
# Nearest to who: age, reid, friendships, daughters, wed, servitude, prison, obnoxious,
# Nearest to and: in, main, unbundling, as, kabaddi, consilience, grimoires, gutrune,
# Nearest to up: saves, tactic, touches, offside, straight, pools, moves, unable,
# Nearest to this: that, of, divides, multiple, constant, second, exactly, the,
# Nearest to can: not, uniquely, usually, qualia, suppose, lid, expression, say,
# Nearest to that: this, return, possible, be, as, therefore, could, every,
# Nearest to accepted: stemming, hypotheses, theorem, embodies, blocs, strabo, limiting, plainly,
# Nearest to channel: fm, stations, broadcasting, radio, channels, broadcast, radios, transmitters,
# Nearest to magazine: collaborative, interview, multimedia, conversation, peer, autobiographical, magazines, newspaper,
# Nearest to mean: parameter, integrals, calculated, geometric, about, ei, we, above,
# Nearest to versions: compiled, version, hints, gui, platforms, pcs, perl, mac,
# Nearest to something: we, know, ve, else, conversation, going, isn, wrong,
# Nearest to construction: metro, petroleum, rail, suburbs, trains, transportation, commuter, investments,
# Nearest to report: drug, assessment, agency, summary, review, investigation, bureau, responsibility,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.1617 0.0310 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.1691 0.0301 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.2070 0.0290 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.2558 0.0292 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.1743 0.0292 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.0900 0.0293 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.1438 0.0292 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.1794 0.0293 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.1425 0.0291 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.1654 0.0293 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, eight,
# Nearest to after: went, second, half, victories, finished, managed, during, playoff,
# Nearest to who: obnoxious, reid, yahweh, susanna, friendships, age, staying, servitude,
# Nearest to and: in, unbundling, main, consilience, kabaddi, freedesktop, by, as,
# Nearest to up: saves, kick, ctrl, offside, drop, straight, unable, xxxg,
# Nearest to this: that, second, of, multiple, constant, exactly, divides, the,
# Nearest to can: uniquely, expression, not, qualia, t, suppose, usually, be,
# Nearest to that: this, be, possible, but, as, return, example, indeed,
# Nearest to accepted: stemming, hypotheses, plainly, heresy, transubstantiation, endorsed, mathematics, judaica,
# Nearest to channel: fm, stations, channels, broadcasting, radio, broadcast, transmitters, radios,
# Nearest to magazine: collaborative, conversation, peer, cartoons, interview, magazines, multimedia, autobiographical,
# Nearest to mean: parameter, integrals, about, we, calculated, geometric, above, difference,
# Nearest to versions: compiled, hints, version, gui, perl, feature, mac, platforms,
# Nearest to something: know, we, ve, else, just, isn, going, conversation,
# Nearest to construction: metro, petroleum, rail, trains, transportation, investments, commuter, dun,
# Nearest to report: assessment, bureau, review, summary, drug, investigation, reports, responsibility,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.1554 0.0298 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.1636 0.0291 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.1359 0.0296 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.1588 0.0295 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.1599 0.0290 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.1640 0.0293 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.1572 0.0294 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.0764 0.0290 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.1092 0.0291 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0883 0.0292 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, eight,
# Nearest to after: went, second, half, managed, the, until, during, weeks,
# Nearest to who: yahweh, servitude, obnoxious, cor, nestorianism, exhortation, age, friendships,
# Nearest to and: in, main, unbundling, as, rajonas, during, consilience, with,
# Nearest to up: saves, xxxg, unable, winger, volkssturm, ctrl, drop, offside,
# Nearest to this: that, second, of, multiple, constant, the, divides, olissipo,
# Nearest to can: uniquely, qualia, usually, not, be, say, lid, assessing,
# Nearest to that: this, could, possible, return, be, assumed, as, but,
# Nearest to accepted: stemming, plainly, hypotheses, blocs, endorsed, heresy, transubstantiation, mathematics,
# Nearest to channel: fm, channels, broadcasting, stations, radio, transmitters, broadcast, radios,
# Nearest to magazine: collaborative, conversation, magazines, interview, cartoons, newspaper, peer, updated,
# Nearest to mean: parameter, integrals, about, we, calculated, geometric, difference, weighted,
# Nearest to versions: compiled, version, hints, gui, perl, feature, freeware, mac,
# Nearest to something: know, we, ve, going, else, isn, remember, conversation,
# Nearest to construction: metro, rail, trains, constructed, suburbs, transportation, residence, commuter,
# Nearest to report: assessment, review, summary, bureau, reports, investigation, agency, news,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.1531 0.0303 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.2257 0.0293 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.2401 0.0292 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.1805 0.0293 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 4.1220 0.0293 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 4.1251 0.0290 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0994 0.0295 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 4.0698 0.0294 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0633 0.0294 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7330 0.0288 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8422 0.0293 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8763 0.0291 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8329 0.0290 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8532 0.0293 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8671 0.0293 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8697 0.0291 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, nine,
# Nearest to after: went, until, second, the, weeks, finished, next, playoff,
# Nearest to who: ceo, to, older, combative, preyed, better, being, wmo,
# Nearest to and: in, the, of, with, also, as, a, are,
# Nearest to up: getz, saves, ctrl, take, pick, make, like, with,
# Nearest to this: that, the, of, all, both, will, thus, is,
# Nearest to can: usually, not, limited, uniquely, appropriate, reads, components, adiabatic,
# Nearest to that: this, be, the, it, to, a, was, there,
# Nearest to accepted: noted, settle, endorsed, early, divorced, although, approaches, rejected,
# Nearest to channel: channels, fm, broadcasting, pbs, itv, transmitters, screened, tvs,
# Nearest to magazine: magazines, toonopedia, monthly, peer, researching, interview, astounding, october,
# Nearest to mean: weighted, intimacy, difference, interquartile, parameter, geometric, sofia, variability,
# Nearest to versions: version, fuselage, patches, activision, hints, vertigo, feature, executables,
# Nearest to something: know, negating, wholesome, ve, going, isn, conversation, parsed,
# Nearest to construction: constructed, concrete, buildings, cement, gates, hsbc, portland, eiffel,
# Nearest to report: summary, reports, assessment, review, news, listings, reuters, pdf,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7881 0.0299 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8170 0.0290 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8782 0.0292 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8247 0.0290 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8307 0.0291 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8227 0.0291 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8254 0.0290 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8020 0.0289 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8554 0.0291 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8433 0.0291 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, nine,
# Nearest to after: went, until, officially, the, second, came, weeks, expelled,
# Nearest to who: to, older, those, ceo, wmo, adopting, group, combative,
# Nearest to and: in, the, of, with, main, by, on, also,
# Nearest to up: ctrl, calculates, saves, take, anglesey, sessions, womanhood, com,
# Nearest to this: that, the, of, all, in, both, and, most,
# Nearest to can: not, appropriate, usually, limited, qualia, peg, adiabatic, strenuous,
# Nearest to that: this, it, the, be, to, was, would, clearly,
# Nearest to accepted: noted, rejected, settle, endorsed, divorced, least, was, early,
# Nearest to channel: channels, fm, broadcasting, pbs, transmitters, itv, tvs, broadcast,
# Nearest to magazine: magazines, toonopedia, monthly, peer, october, astounding, collaborative, harper,
# Nearest to mean: intimacy, weighted, parameter, interquartile, difference, geometric, sofia, propto,
# Nearest to versions: version, activision, hints, feature, executables, patches, fuselage, vertigo,
# Nearest to something: know, negating, going, wholesome, ve, isn, conversation, what,
# Nearest to construction: constructed, concrete, buildings, eiffel, cement, gates, pier, portland,
# Nearest to report: summary, reports, pdf, assessment, review, reuters, ipcc, news,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8341 0.0302 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8092 0.0290 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7929 0.0290 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7420 0.0290 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8432 0.0292 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7940 0.0294 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9232 0.0290 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8815 0.0290 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8398 0.0289 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8088 0.0290 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, nine,
# Nearest to after: went, until, weeks, second, came, officially, expelled, the,
# Nearest to who: combative, whom, elite, those, ceo, older, them, anyone,
# Nearest to and: in, the, with, of, are, by, on, main,
# Nearest to up: sessions, calculates, make, around, womanhood, ctrl, when, getz,
# Nearest to this: that, the, all, of, in, for, happen, and,
# Nearest to can: not, usually, appropriate, qualia, limited, hence, be, occasionally,
# Nearest to that: it, this, be, the, was, would, to, a,
# Nearest to accepted: noted, settle, endorsed, rejected, least, was, early, repudiation,
# Nearest to channel: channels, fm, broadcasting, itv, pbs, tvs, transmitters, broadcast,
# Nearest to magazine: magazines, monthly, caliber, harper, october, peer, astounding, toonopedia,
# Nearest to mean: weighted, intimacy, difference, parameter, interquartile, geometric, avoirdupois, sofia,
# Nearest to versions: version, hints, feature, patches, fuselage, typefaces, executables, butchers,
# Nearest to something: know, negating, ve, wholesome, isn, going, conversation, relies,
# Nearest to construction: constructed, concrete, buildings, eiffel, portland, gates, cement, busing,
# Nearest to report: summary, reports, assessment, reuters, pdf, investigation, news, listings,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7745 0.0300 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7843 0.0300 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7557 0.0298 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8106 0.0298 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7758 0.0295 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8058 0.0293 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7943 0.0220 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7963 0.0289 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8128 0.0292 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8362 0.0287 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, nine,
# Nearest to after: went, second, until, weeks, the, officially, ultimately, came,
# Nearest to who: to, combative, older, those, whom, elite, ceo, individuals,
# Nearest to and: in, the, of, with, by, are, also, a,
# Nearest to up: getz, when, around, astonished, take, womanhood, sessions, make,
# Nearest to this: the, that, of, all, thus, to, in, and,
# Nearest to can: usually, limited, appropriate, not, qualia, adiabatic, angolan, are,
# Nearest to that: this, it, to, be, the, was, would, does,
# Nearest to accepted: endorsed, noted, was, there, settle, early, rejected, divorced,
# Nearest to channel: channels, fm, tvs, aired, broadcasting, itv, pbs, transmitters,
# Nearest to magazine: magazines, caliber, peer, monthly, october, flatly, dope, updated,
# Nearest to mean: weighted, intimacy, interquartile, difference, parameter, geometric, variability, about,
# Nearest to versions: version, patches, fuselage, vhdl, executables, hints, feature, mac,
# Nearest to something: know, negating, wholesome, ve, going, isn, relies, conversation,
# Nearest to construction: constructed, concrete, buildings, gates, eiffel, busing, portland, pier,
# Nearest to report: summary, pdf, reports, chronology, review, astronautica, news, assessment,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7913 0.0300 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8404 0.0296 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7404 0.0298 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8366 0.0290 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8171 0.0291 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8234 0.0293 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8464 0.0290 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7005 0.0290 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7737 0.0290 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7556 0.0293 sec/batch
# Nearest to two: zero, three, four, five, one, seven, six, nine,
# Nearest to after: went, until, second, came, weeks, officially, next, the,
# Nearest to who: combative, older, those, to, elite, individuals, them, wmo,
# Nearest to and: in, of, the, with, are, by, for, also,
# Nearest to up: when, take, with, sessions, make, womanhood, astonished, apartments,
# Nearest to this: that, the, of, is, for, thus, all, to,
# Nearest to can: not, usually, limited, appropriate, such, be, components, efficiently,
# Nearest to that: this, it, the, be, to, was, does, a,
# Nearest to accepted: noted, endorsed, was, although, early, there, rejected, accept,
# Nearest to channel: channels, fm, tvs, itv, pbs, broadcasting, aired, ctv,
# Nearest to magazine: magazines, peer, monthly, caliber, october, flatly, interview, toonopedia,
# Nearest to mean: weighted, intimacy, interquartile, difference, geometric, variability, parameter, about,
# Nearest to versions: version, fuselage, patches, feature, butchers, vhdl, hints, typefaces,
# Nearest to something: know, negating, wholesome, ve, relies, isn, going, conversation,
# Nearest to construction: constructed, concrete, gates, busing, highways, analytic, pier, cannons,
# Nearest to report: summary, pdf, reports, listings, assessment, news, reuters, review,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7866 0.0300 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7834 0.0290 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8148 0.0291 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7453 0.0293 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7833 0.0288 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8513 0.0290 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7682 0.0291 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7757 0.0292 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7871 0.0288 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7497 0.0288 sec/batch
# Nearest to two: zero, three, four, one, five, seven, six, nine,
# Nearest to after: until, went, second, next, the, weeks, solidly, half,
# Nearest to who: to, older, combative, those, whom, wmo, elite, ceo,
# Nearest to and: in, of, the, with, by, are, a, for,
# Nearest to up: sessions, getz, anglesey, calculates, pick, with, take, a,
# Nearest to this: the, that, of, all, and, is, in, but,
# Nearest to can: not, limited, such, be, usually, appropriate, hence, are,
# Nearest to that: it, the, be, this, was, a, is, to,
# Nearest to accepted: noted, was, rejected, although, endorsed, early, divorced, proposed,
# Nearest to channel: channels, fm, tvs, pbs, itv, ctv, broadcasting, telekom,
# Nearest to magazine: magazines, peer, toonopedia, caliber, astounding, october, monthly, periodicals,
# Nearest to mean: intimacy, weighted, interquartile, variability, difference, sofia, avoirdupois, about,
# Nearest to versions: version, fuselage, hints, feature, text, patches, butchers, typefaces,
# Nearest to something: know, negating, going, ve, isn, wholesome, relies, wasn,
# Nearest to construction: constructed, concrete, gates, eiffel, buildings, busing, highways, pier,
# Nearest to report: summary, pdf, reports, listings, assessment, review, reuters, investigation,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7664 0.0300 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7907 0.0298 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7874 0.0292 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7705 0.0292 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8259 0.0291 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7513 0.0293 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7782 0.0291 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7981 0.0292 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7451 0.0291 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7523 0.0291 sec/batch
# Nearest to two: zero, three, four, one, five, seven, six, nine,
# Nearest to after: until, went, second, officially, next, the, weeks, half,
# Nearest to who: to, those, them, older, elite, combative, being, whom,
# Nearest to and: in, of, the, with, are, as, by, a,
# Nearest to up: a, to, with, of, through, when, make, calculates,
# Nearest to this: the, of, that, in, and, but, to, all,
# Nearest to can: not, be, usually, to, limited, are, appropriate, such,
# Nearest to that: it, the, be, was, this, to, of, a,
# Nearest to accepted: noted, rejected, was, endorsed, proposed, accept, early, settle,
# Nearest to channel: channels, fm, pbs, itv, ctv, tvs, telekom, broadcasting,
# Nearest to magazine: magazines, caliber, periodicals, monthly, peer, october, astounding, flatly,
# Nearest to mean: weighted, interquartile, intimacy, difference, geometric, variability, parameter, avoirdupois,
# Nearest to versions: version, fuselage, feature, patches, hints, vhdl, executables, typefaces,
# Nearest to something: know, negating, isn, going, ve, wholesome, meaning, relies,
# Nearest to construction: constructed, concrete, gates, busing, eiffel, pier, highways, thoroughfares,
# Nearest to report: summary, pdf, assessment, reports, ipcc, listings, reuters, review,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8053 0.0302 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7715 0.0291 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8948 0.0290 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8307 0.0290 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8710 0.0290 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7764 0.0289 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7161 0.0293 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7705 0.0290 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6671 0.0290 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7798 0.0289 sec/batch
# Nearest to two: zero, three, four, one, five, seven, six, nine,
# Nearest to after: until, went, second, officially, weeks, the, expelled, came,
# Nearest to who: to, those, combative, whom, elite, them, up, older,
# Nearest to and: in, of, the, with, by, are, as, for,
# Nearest to up: with, to, who, getz, when, a, through, sessions,
# Nearest to this: the, that, of, all, to, but, happen, in,
# Nearest to can: not, such, limited, be, adiabatic, usually, hence, appropriate,
# Nearest to that: it, was, the, to, could, this, be, of,
# Nearest to accepted: noted, rejected, was, endorsed, accept, repudiation, settle, purer,
# Nearest to channel: channels, fm, pbs, itv, ctv, tvs, telekom, broadcasting,
# Nearest to magazine: magazines, caliber, peer, monthly, flatly, october, interview, cyborgs,
# Nearest to mean: weighted, interquartile, intimacy, difference, parameter, geometric, avoirdupois, variability,
# Nearest to versions: version, feature, fuselage, patches, executables, hints, vhdl, vertigo,
# Nearest to something: know, negating, isn, ve, going, uh, wholesome, payouts,
# Nearest to construction: constructed, concrete, busing, gates, completed, analytic, highways, functional,
# Nearest to report: pdf, summary, assessment, reports, ipcc, reuters, listings, pullout,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7442 0.0302 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7587 0.0290 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
